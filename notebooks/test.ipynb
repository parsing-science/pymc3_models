# %%
def my_function(food_type='cheese', inference_args={}):
    if food_type == 'cheese':
        cheese(**inference_args)

# %%
def cheese(hard, no=5):
    print(hard)
    print(no)

# %%
my_function('cheese', {'hard': 'blah', 'no': 10})
# Out:
# blah
# 10
